# %% [markdown]
# # Titanic Dataset

# %% [markdown]
# ## Steps
#
#
# 1. Importing libraries
#
# 2. Loading the dataset
#
# 3. Previewing the dataset - info, shape, random sample of dataset, first and last five records
#
# 4. Feature engineering
#
# 5. Cleaning Dataset:
#     - Checking for anormalies
#     - Checking for duplicates
#     - Checking for missing values
#     - Checking for outliers
#
# 6. Exploratory data analysis
#     - Univariate analysis
#     - Bivariate analysis
#
#
#
#
# ## Variable Notes
#
#
# 1. pclass: A proxy for socio-economic status (SES)
#
#     - 1st = Upper
#     - 2nd = Middle
#     - 3rd = Lower
#
# 2. age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
#
# 3. sibsp: The dataset defines family relations in this way...
#
#     - Sibling = brother, sister, stepbrother, stepsister
#     - Spouse = husband, wife (mistresses and fiancés were ignored)
#
#
# 4. parch: The dataset defines family relations in this way...
#
#     - Parent = mother, father
#     - Child = daughter, son, stepdaughter, stepson
#     - Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ## Importing libraries

# %%
# importing libraries

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Loading dataset

# %%
# loading titatnic data set

Train = pd.read_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9189a608edfe> in <module>
#       1 # loading titatnic data set
#       2
# ----> 3 Train = pd.read_csv("train.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %% [markdown]
# ## Previewing dataset

# %%
# previewing first five records

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# previewing last five records

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# previeiwing a random sample of 10 records

df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 226          227         1       2
# 408          409         0       3
# 7              8         0       3
# 598          599         0       3
# 667          668         0       3
# 46            47         0       3
# 694          695         0       1
# 509          510         1       3
# 394          395         1       3
# 129          130         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 226                          Mellors, Mr. William John    male  19.0      0
# 408                  Birkeland, Mr. Hans Martin Monsen    male  21.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 598                                  Boulos, Mr. Hanna    male   NaN      0
# 667                         Rommetvedt, Mr. Knud Paust    male   NaN      0
# 46                                   Lennon, Mr. Denis    male   NaN      1
# ...

# %%
# Previewing shape of data frame

rows, columns = df.shape


# print the number rows and columns in dataframe

print(f"Number of rows: {rows}, Number of columns: {columns}")
# Out:
# Number of rows: 891, Number of columns: 12

# %%
# Previewing columns in dataframe

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Preview the information in dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.sample(10)

print(df.SibSp.value_counts())
print(df.Parch.value_counts())
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# To check which are all the columns having numerical values

numerics = ['int16', 'int32', 'int64', 'float64']


# Numerical Columns

num = df.select_dtypes(include=numerics).columns.to_list()


# preview numerical columns

num
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# to check which are all the columns having categorical values (except numerical colums)

cat=[i for i in df.columns if i not in num]


# non_numerical variables

cat
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# - survived, pclass, embarked and sex have inappropiate datatypes should be categorical variables

# %%
# Describe dataset

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# save a copy of original dataset

df_original = df.copy()

# %% [markdown]
# ## Feature engineering

# %%
# extracting the title of passanger from name column


df['title'] = df['Name'].apply(lambda x : x.split('.')[0].strip())


# Extracting the Title further from name column

df['title'] = df['title'].apply(lambda x : x.split(',')[1].strip())


# extract the Family Name from Name column

df['FamilyName'] = df['Name'].apply(lambda x : x.split(',')[0].strip())


# top 10 records

df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df[df['FamilyName'] == 'Andersson']
df.FamilyName.value_counts().head(15)
# Out:
# Andersson    9
# Sage         7
# Panula       6
# Skoog        6
# Carter       6
# Goodwin      6
# Johnson      6
# Rice         5
# Lefebre      4
# Asplund      4
# Harris       4
# Fortune      4
# Baclini      4
# Brown        4
# Hart         4
# Name: FamilyName, dtype: int64

# %%
# Creating age group column

# initializing bins for the different age groups
bins= [0, 5, 10, 18, 36, 66, 130]

# initializing labels for different age groups
labels = ['Infant', 'Kids', 'Teen', 'Youth', 'Adult', 'Senior Citizen']

#  segmenting and sorting data values into bins
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right = False)

df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 21            22         1       2                    Beesley, Mr. Lawrence
# 802          803         1       1      Carter, Master. William Thornton II
# 570          571         1       2                       Harris, Mr. George
# 586          587         0       2                  Jarvis, Mr. John Denzil
# 723          724         0       2                  Hodges, Mr. Henry Price
# 291          292         1       1  Bishop, Mrs. Dickinson H (Helen Walton)
# 398          399         0       2                         Pain, Dr. Alfred
# 249          250         0       2            Carter, Rev. Ernest Courtenay
# 297          298         0       1             Allison, Miss. Helen Loraine
# 123          124         1       2                      Webber, Miss. Susan
#
#         Sex   Age  SibSp  Parch       Ticket      Fare    Cabin Embarked  \
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Validity

# %%
# initializing a list of categorical columns

columns = ['Survived', 'Sex', 'Pclass', 'Embarked', 'AgeGroup']


# Converting  columns in dataframe from int and object datatypes to categorical data types

for col in columns:
    df[col] = df[col].astype('category')

# %%
# check datatypes of variables in dataframe
df.dtypes
# Out:
# PassengerId       int64
# Survived       category
# Pclass         category
# Name             object
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# title            object
# FamilyName       object
# AgeGroup       category
# dtype: object

# %% [markdown]
# ### Duplicates

# %%
# Checking for duplicates in dataframe

duplicates = df.duplicated().any()


# if statement that prints there are duplicates if it returns a true value else prints there are no duplicates

if duplicates == True:
    print("There are duplicate records in this dataframe")
else: 
    print("There are no duplicate records in this dataframe")
# Out:
# There are no duplicate records in this dataframe

# %% [markdown]
# ## Missing values

# %%
# Checking for missing values in dataframe

df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# title          False
# FamilyName     False
# AgeGroup        True
# dtype: bool

# %%
# print

print("There are missing values in the age, cabin and embarked columns")
# Out:
# There are missing values in the age, cabin and embarked columns

# %%
# cheking total number of missing values in the dataframe

print(f"""
There are:

{df.isnull().sum()}

missing values in the dataframe
""")
# Out:
# There are:
#
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# title            0
# FamilyName       0
# AgeGroup       177
# dtype: int64
#
# missing values in the dataframe

# %%
# Missing values as a percentage of total records in dataset

percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# title           0.000000
# FamilyName      0.000000
# AgeGroup       19.865320
# dtype: float64

# %%
# Visualize missing values

sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Dealing with missing values in cabin column

# %% [markdown]
# - Cabin has over half of all its records missing. The column shall be dropped

# %%
# dropping the cabin column

del df["Cabin"]

# %%
# Checking columns in dataframe to confirm cabin column has been dropped

print(df.columns)

print("""

Cabin column has been succefully dropped
""")
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'title', 'FamilyName',
#        'AgeGroup'],
#       dtype='object')
#
#
# Cabin column has been succefully dropped

# %% [markdown]
# #### Dealing with missing values in embarked column

# %%
# previewing missing values in embarked column

df[df.Embarked.isnull()]
# Out:
#      PassengerId Survived Pclass                                       Name  \
# 61            62        1      1                        Icard, Miss. Amelie
# 829          830        1      1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked title FamilyName  \
# 61   female  38.0      0      0  113572  80.0      NaN  Miss      Icard
# 829  female  62.0      0      0  113572  80.0      NaN   Mrs      Stone
#
#     AgeGroup
# 61     Adult
# 829    Adult

# %%
# Preview unique records in embarked column of dataframe

df.Embarked.unique()
# Out:
# ['S', 'C', 'Q', NaN]
# Categories (3, object): ['C', 'Q', 'S']

# %%
# Preview value counts as a percentage of total unique records in embarked column of dataframe

df.Embarked.value_counts() / len(df) * 100
# Out:
# S    72.278339
# C    18.855219
# Q     8.641975
# Name: Embarked, dtype: float64

# %%
# dropping missing value with the most common records in embarked column 'S'

df = df[df['Embarked'].notna()]

# %%
# replacing missing value with the most common records in embarked column 'S'

# df.Embarked.fillna(value = "S", inplace = True)

# %%
# Preview unique records in embarked column of dataframe to confirm missing values have been replaced
df.Embarked.unique()
# Out:
# ['S', 'C', 'Q']
# Categories (3, object): ['C', 'Q', 'S']

# %% [markdown]
# - Missing values have succefully been replaced

# %% [markdown]
# #### Dealing with missing values in embarked column

# %%
# previewing a sample of 10 records with age as missing value
df[df.Age.isnull()].sample(10)
# Out:
#      PassengerId Survived Pclass                            Name     Sex  Age  \
# 692          693        1      3                    Lam, Mr. Ali    male  NaN
# 502          503        0      3  O'Sullivan, Miss. Bridget Mary  female  NaN
# 223          224        0      3            Nenkoff, Mr. Christo    male  NaN
# 264          265        0      3              Henry, Miss. Delia  female  NaN
# 768          769        0      3             Moran, Mr. Daniel J    male  NaN
# 596          597        1      2      Leitch, Miss. Jessie Wills  female  NaN
# 48            49        0      3             Samaan, Mr. Youssef    male  NaN
# 793          794        0      1        Hoyt, Mr. William Fisher    male  NaN
# 95            96        0      3     Shorney, Mr. Charles Joseph    male  NaN
# 792          793        0      3         Sage, Miss. Stella Anna  female  NaN
#
#      SibSp  Parch    Ticket     Fare Embarked title  FamilyName AgeGroup
# ...

# %%
# Getting a summary statistic of ages for those who survived (1), and those who did not survive(0)

df.groupby([ 'Sex', 'Pclass'])['Age'].describe()
# Out:
#                count       mean        std   min     25%   50%    75%   max
# Sex    Pclass
# female 1        83.0  34.240964  13.430572  2.00  23.000  35.0  44.00  63.0
#        2        74.0  28.722973  12.872702  2.00  22.250  28.0  36.00  57.0
#        3       102.0  21.750000  12.729964  0.75  14.125  21.5  29.75  63.0
# male   1       101.0  41.281386  15.139570  0.92  30.000  40.0  51.00  80.0
#        2        99.0  30.740707  14.793894  0.67  23.000  30.0  36.75  70.0
#        3       253.0  26.507589  12.159514  0.42  20.000  25.0  33.00  74.0

# %%
# replacing missing values in age with the median values of ages grouped by pclass, and sex

df['Age'].fillna(df.groupby(["Sex","Pclass"])['Age'].transform('median'),inplace=True)

# %%
# check for any remaining null values in dataframe

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# title            0
# FamilyName       0
# AgeGroup       177
# dtype: int64

# %% [markdown]
# - All missing values have been succefully dealt with

# %% [markdown]
# #### Age Group

# %%
# Replacing Missing values in age group column

# initializing bins for the different age groups

bins= [0, 5, 10, 18, 36, 66, 130]


# initializing labels for different age groups

labels = ['Infant', 'Kids', 'Teen', 'Youth', 'Adult', 'Senior Citizen']


#  segmenting and sorting data values into bins

df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right = False)

df.sample(10)
# Out:
#      PassengerId Survived Pclass  \
# 458          459        1      2
# 656          657        0      3
# 290          291        1      1
# 150          151        0      2
# 733          734        0      2
# 710          711        1      1
# 206          207        0      3
# 408          409        0      3
# 756          757        0      3
# 379          380        0      3
#
#                                                  Name     Sex   Age  SibSp  \
# 458                               Toomey, Miss. Ellen  female  50.0      0
# 656                             Radeff, Mr. Alexander    male  25.0      0
# 290                      Barber, Miss. Ellen "Nellie"  female  26.0      0
# 150                        Bateman, Rev. Robert James    male  51.0      0
# 733                        Berriman, Mr. William John    male  23.0      0
# 710  Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")  female  24.0      0
# ...

# %% [markdown]
# ### Outliers

# %% [markdown]
# #### Detection - Box Plots

# %%
# boxplots for Age

plt.boxplot(df['Age'], vert = True, patch_artist = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20edfd56190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20edfd567f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20edfd41d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x20edfd56f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20edfd5f2e0>],
#  'means': []}

# %%
# boxplots for fare

plt.boxplot(df['Fare'], vert = True, patch_artist = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20edfdcb100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20edfdcb820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20edfdbcd30>],
#  'medians': [<matplotlib.lines.Line2D at 0x20edfdcbf40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20edfdd7310>],
#  'means': []}

# %%
# passengers with 
df[df['Fare'] > 400]
# Out:
#      PassengerId Survived Pclass                                Name     Sex  \
# 258          259        1      1                    Ward, Miss. Anna  female
# 679          680        1      1  Cardeza, Mr. Thomas Drake Martinez    male
# 737          738        1      1              Lesurer, Mr. Gustave J    male
#
#       Age  SibSp  Parch    Ticket      Fare Embarked title FamilyName AgeGroup
# 258  35.0      0      0  PC 17755  512.3292        C  Miss       Ward    Youth
# 679  36.0      0      1  PC 17755  512.3292        C    Mr    Cardeza    Adult
# 737  35.0      0      0  PC 17755  512.3292        C    Mr    Lesurer    Youth

# %% [markdown]
# #### Detection - Histograms

# %%
# Ploting histograms of fares

plt.hist(df['Fare'], bins = 10)
# Out:
# (array([732., 104.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
# ploting histogram of passenger ages

plt.hist(df['Age'], bins = 10)
# Out:
# (array([ 54.,  46., 219., 274., 147.,  70.,  45.,  23.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Skewness
#
# - the skewness value should be within the range of -1 to 1 for a normal distribution, any major changes from this value may indicate the presence of outliers.

# %%
# skewness of  fare and age variables in dataset

print('skewness value of Age: ',df['Age'].skew())
print('skewness value of Fare: ',df['Fare'].skew())
# Out:
# skewness value of Age:  0.5325738791317377
# skewness value of Fare:  4.801440211044194

# %% [markdown]
# - from the result above, the ‘Fare’ skewness value of 4.78 shows the variable has been rightly skewed, indicating the presence of outliers.

# %% [markdown]
# #### Interquartile Range(IQR)

# %%
# First quartile\
Q1 = df['Fare'].quantile(0.25)

# Second Quartile

Q3 = df['Fare'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 23.1042

# %%
# initializing whisker width

whisker_width = 1.5


# get the outlier records in dataset

Fare_outliers = df[(df['Fare'] < (Q1 - (whisker_width*IQR))) | (df['Fare'] > (Q3 + (whisker_width*IQR)))]


# first five outlier records

Fare_outliers.head()
# Out:
#     PassengerId Survived Pclass  \
# 1             2        1      1
# 27           28        0      1
# 31           32        1      1
# 34           35        0      1
# 52           53        1      1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.0      1
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
#
#     Parch    Ticket      Fare Embarked title FamilyName AgeGroup
# 1       0  PC 17599   71.2833        C   Mrs    Cumings    Adult
# 27      2     19950  263.0000        S    Mr    Fortune    Youth
# 31      0  PC 17569  146.5208        C   Mrs    Spencer    Youth
# ...

# %%
# describing the outliers in the dataset

Fare_outliers.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   114.000000  114.000000  114.000000  114.000000  114.000000
# mean    447.315789   33.468596    1.114035    0.666667  129.138851
# std     235.767221   13.859230    1.903694    0.889135   85.136315
# min       2.000000    0.920000    0.000000    0.000000   66.600000
# 25%     271.500000   23.250000    0.000000    0.000000   78.035400
# 50%     403.500000   34.000000    1.000000    0.000000   90.539600
# 75%     659.000000   40.750000    1.000000    1.000000  150.292700
# max     880.000000   70.000000    8.000000    4.000000  512.329200

# %%
# outliers per class

Fare_outliers.Pclass.value_counts()
# Out:
# 1    102
# 3      7
# 2      5
# Name: Pclass, dtype: int64

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Univariate analysis
#
# #### value counts

# %%
#  columns list

columns = ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch',  'Embarked', 'AgeGroup']


# loop through columns to get value counts in each variables

for col in columns:
    counts = df[col].value_counts()
    print(counts)
# Out:
# 0    549
# 1    340
# Name: Survived, dtype: int64
# 3    491
# 1    214
# 2    184
# Name: Pclass, dtype: int64
# male      577
# female    312
# Name: Sex, dtype: int64
# 0    606
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# 0    676
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# Youth             540
# Adult             228
# Teen               51
# Infant             40
# Kids               22
# Senior Citizen      8
# Name: AgeGroup, dtype: int64

# %% [markdown]
# #### summary statistics of continuos variables

# %%
# columns

columns = ["Age", "Fare"]


# loop through columns to get summary statistics in each variable

for col in columns:
    
    stats = df[col].describe()
    skewness = df[col].skew()
    kurtosis = df[col].kurt()
    
    print(f"""
    {stats}
    
    Skew {col}: {skewness}
    
    Kurtosis {col}: {kurtosis}
    """)
# Out:
#     count    889.000000
# mean      29.065433
# std       13.270162
# min        0.420000
# 25%       21.500000
# 50%       26.000000
# 75%       36.000000
# max       80.000000
# Name: Age, dtype: float64
#
#     Skew Age: 0.5325738791317377
#
#     Kurtosis Age: 0.7287292711659408
#
#
#     count    889.000000
# mean      32.096681
# std       49.697504
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64
#
#     Skew Fare: 4.801440211044194
#
#     Kurtosis Fare: 33.508477269700144

# %% [markdown]
# #### Visualizations - Pie plots

# %%
#  Pie chart of survivors

df.groupby('Survived').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
#  Pie chart of gender of passengers

df.groupby('Sex').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
#  Pie chart of pclass of passenger

df.groupby('Pclass').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
#  Pie chart of  stations passengers boarded

df.groupby('Embarked').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
#  Pie chart of  stations passengers boarded

df.groupby('AgeGroup').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# #### Visualizations - barplots

# %%
# countplot of parch

sns.countplot(x= 'AgeGroup', data = df)
# Out:
# <AxesSubplot:xlabel='AgeGroup', ylabel='count'>

# %%
# countplot of parch

sns.countplot(x= 'Parch', data = df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
# Count plot of sibsp

sns.countplot(x= 'SibSp', data = df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %% [markdown]
# ### visualizations - histogram plot

# %%
# Ploting histograms of fares

plt.hist(df['Age'], bins = 10)
# Out:
# (array([ 54.,  46., 219., 274., 147.,  70.,  45.,  23.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# Ploting histograms of Ages

plt.hist(df['Fare'], bins = 10)
# Out:
# (array([732., 104.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Analysis

# %%
# Getting value counts of survivors per sex

survivors_sex = df.groupby(['Sex'])['Survived'].value_counts()
survivors_sex
# Out:
# Sex
# female  1    231
#         0     81
# male    0    468
#         1    109
# Name: Survived, dtype: int64

# %%
# Getting value counts of survivors per class

survivors_class = df.groupby(['Pclass'])['Survived'].value_counts()
survivors_class
# Out:
# Pclass
# 1       1    134
#         0     80
# 2       0     97
#         1     87
# 3       0    372
#         1    119
# Name: Survived, dtype: int64

# %%
# Getting value counts of survivors per age group

survivors_agegroup = df.groupby(['AgeGroup'])['Survived'].value_counts()
survivors_agegroup
# Out:
# AgeGroup
# Infant          1     27
#                 0     13
# Kids            0     11
#                 1     11
# Teen            0     28
#                 1     23
# Youth           0    347
#                 1    193
# Adult           0    143
#                 1     85
# Senior Citizen  0      7
#                 1      1
# Name: Survived, dtype: int64

# %% [markdown]
# #### Correlations

# %%
# coreelations between the numerical variables in datase

df.corr()
# Out:
#              PassengerId       Age     SibSp     Parch      Fare
# PassengerId     1.000000  0.036233 -0.057686 -0.001657  0.012703
# Age             0.036233  1.000000 -0.249161 -0.174541  0.119859
# SibSp          -0.057686 -0.249161  1.000000  0.414542  0.160887
# Parch          -0.001657 -0.174541  0.414542  1.000000  0.217532
# Fare            0.012703  0.119859  0.160887  0.217532  1.000000

# %%
# plot of correlation

sns.heatmap(df.corr(), annot = True, linewidth = 5, cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# - All Variables are poorly correlated

# %% [markdown]
# #### Joint plot

# %%
# joint plot of ages and fares in titanic with regresson line

sns.jointplot(x = 'Fare' , y = 'Age' , data = df, kind = 'reg')

# %%
# joint plot of parch and fares in titanic with regresson line

sns.jointplot(x = 'Fare' , y = 'Parch' , data = df, kind = 'reg')

# %%
# joint plot of Sibsp and fares in titanic with regresson line

sns.jointplot(x = 'Fare' , y = 'SibSp' , data = df, kind = 'reg')

# %% [markdown]
# #### Pairplot

# %%
# pair plot with sex as hue

sns.pairplot(df, hue ="Sex")

# %%
# pair plot with Survived as hue

sns.pairplot(df, hue ="Survived")

# %%
# pair plot with Pclass as hue

sns.pairplot(df, hue ="Pclass")

# %% [markdown]
# #### Violinplot

# %%
# violinplot of Ages vs Pclass

sns.violinplot(x = 'Age', y = 'Pclass', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %%
# violinplot of Ages vs Sex

sns.violinplot(x = 'Age', y = 'Sex', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
# violinplot of Ages vs Embarked

sns.violinplot(x = 'Age', y = 'Embarked', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Embarked'>

# %%
# violinplot of Ages vs Agegroup

sns.violinplot(x = 'Age', y = 'AgeGroup', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='AgeGroup'>

# %%
# violinplot of Fare vs AgeGroup

sns.violinplot(x = 'Fare', y = 'AgeGroup', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='AgeGroup'>

# %%
# violinplot of Fares vs Pclass

sns.violinplot(x = 'Fare', y = 'Pclass', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Pclass'>

# %%
# violinplot of Fares vs Embarked

sns.violinplot(x = 'Fare', y = 'Embarked', data =df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Embarked'>
